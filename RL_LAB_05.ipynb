# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51899/RL/blob/main/RL_LAB_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym

def random_agent(env_name):
    env = gym.make(env_name)

    state, info = env.reset()

    total_reward = 0
    steps = 0

    while True:
        action = env.action_space.sample()

        next_state, reward, terminated, truncated, info = env.step(action)

        total_reward += reward
        steps += 1

        state = next_state

        if terminated or truncated:
            break

    average_reward = total_reward / steps

    print("\nEnvironment:", env_name)
    print("Total Reward:", total_reward)
    print("Number of Steps:", steps)
    print("Average Reward:", average_reward)

    env.close()


random_agent("CartPole-v1")
random_agent("MountainCar-v0")
random_agent("FrozenLake-v1")
# Out:
# Environment: CartPole-v1
# Total Reward: 11.0
# Number of Steps: 11
# Average Reward: 1.0
#
# Environment: MountainCar-v0
# Total Reward: -200.0
# Number of Steps: 200
# Average Reward: -1.0
#
# Environment: FrozenLake-v1
# Total Reward: 0
# Number of Steps: 5
# Average Reward: 0.0
